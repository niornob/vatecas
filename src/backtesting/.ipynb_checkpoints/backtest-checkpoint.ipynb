# %%
"""
this block is needed at the beginning of all notebooks to be able to load modules
"""
import os
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Automatically find and append the project root
root_path = Path.cwd().resolve().parents[1]  # adjust level as needed
data_path = os.path.join(root_path, "data")
src_path = os.path.join(root_path, "src")

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from signal_generator.signal_module import SignalModule

from signal_generator.regression.Kalman_filter import KalmanFilter
from signal_generator.regression.UKF_log import UKFlog
from signal_generator.regression.lag import Lag
from signal_generator.regression.VAR import VAROracle

from signal_generator.regression.base.oracle_diagnostics import oracle_diagnostics
from backtesting.backtester import BacktestEngine
from portfolio_management.portfolio_registry import PortfolioRegistry
from signal_generator.signal_diagnostics import SignalDiagnostics

# %%
portfolio_registry = PortfolioRegistry()
portfolio_registry.available()
# Out:
# ['default', 'custom0']

# %%
manager = portfolio_registry.get('default')
print(manager.portfolio.initial_time)

initial_time = pd.Timestamp('2022-01-01T12:00:00+00:00')
final_time = pd.Timestamp('2023-01-01T12:00:00+00:00')
# Out:
# 2020-01-01 12:00:00+00:00

# %%
x_vals = np.linspace(0, 10, 100)  # 500 points between 0 and 10

# Evaluate the function
y_vals = np.array(
    [
        manager.frequency_controller._calculate_threshold(
            last_trade_time=initial_time,
            current_time=initial_time + pd.Timedelta(days=x),
        )
        for x in x_vals
    ]
)

# Plot
plt.figure(figsize=(10, 3))
plt.plot(x_vals, y_vals, label="signal threshold", color="blue")
plt.xlabel("days since last trade")
plt.ylabel("f(x)")
plt.title("signal threshold vs days since last trade")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
tickers = ["SPY", "AAPL", "NVDA", "MSFT", "AMZN", "META", "GOOGL", "AVGO", "TSLA", "BRK-B", "GOOG", "JPM"]
#tickers = ["SPY", "AAPL", "NVDA"]
data = {ticker: pd.read_parquet(os.path.join(data_path, f"{ticker}.parquet")) for ticker in tickers}
data = {tk: df.loc[initial_time:final_time] for tk, df in data.items()}

closing_data = {tk: df['adjClose'] for tk, df in data.items()}

# %%
timeline = pd.DatetimeIndex(
    pd.to_datetime(
        sorted(set().union(*[df.index for df in data.values()]))
    )
)
timeline = timeline[timeline>manager.portfolio.initial_time]
aligned = {
    tk: df.reindex(timeline).ffill().fillna(0)
    for tk, df in data.items()
}
closing_data = {tk: df['adjClose'] for tk, df in aligned.items()}

# %%
kalman = KalmanFilter(
    process_noise=1e+3,
    obs_noise_scale=1e-5
)

ukf_log = UKFlog(process_noise=1e-1, obs_noise_scale=1e-1)

lag = Lag(lag_days=1)

var = VAROracle(lag=20)

model = SignalModule(oracle=kalman, smoothing_window=2, market_vol_target=2)

# %%
# model_diagnostic = SignalDiagnostics(signal_module=model, lookback=40)
# model_diagnostic.run(data=closing_data)

# %%
bt = BacktestEngine(data=data, signal_module=model, manager=manager, lookback_days=40)

# %%
bt.run()
# Out:
# Starting backtest for 251 trading days...
# Backtesting: 100%|██████████| 251/251 [00:34<00:00,  7.36it/s]

# %%
#bt.equity_vs_benchmarks_marked(benchmarks=tickers, history=bt.manager.portfolio.order_history)
bt.equity_vs_benchmarks(benchmarks=tickers)

# %%
bt.plot_signals()

# %%
bt.holdings_over_time()

# %% [markdown]
# <h1> Sanity Check </h1>

# %%
bt.manager.portfolio.order_history[:20]
# Out:
# [Order(ticker='TSLA', size=np.float64(24.570386787028802), price=np.float64(290.71), timestamp=Timestamp('2022-03-02 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='GOOG', size=np.float64(44.432263651162856), price=np.float64(133.9652870066), timestamp=Timestamp('2022-03-02 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='GOOGL', size=np.float64(35.54212371075597), price=np.float64(133.9791848303), timestamp=Timestamp('2022-03-02 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='BRK-B', size=np.float64(11.17887996565848), price=np.float64(319.48), timestamp=Timestamp('2022-03-02 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='MSFT', size=np.float64(8.270100706786913), price=np.float64(287.8988376766), timestamp=Timestamp('2022-03-02 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='AAPL', size=np.float64(7.358884814286909), price=np.float64(161.7739943646), timestamp=Timestamp('2022-03-02 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='GOOG', size=np.float64(-44.432263651162856), price=np.float64(135.3289919394), timestamp=Timestamp('2022-03-03 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='GOOGL', size=np.float64(-35.54212371075597), price=np.float64(135.3545245326), timestamp=Timestamp('2022-03-03 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='BRK-B', size=np.float64(-11.17887996565848), price=np.float64(326.63), timestamp=Timestamp('2022-03-03 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='MSFT', size=np.float64(-8.270100706786913), price=np.float64(295.2386204762), timestamp=Timestamp('2022-03-03 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='AAPL', size=np.float64(-7.358884814286909), price=np.float64(165.7890676477), timestamp=Timestamp('2022-03-03 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='TSLA', size=np.float64(40.2947948850286), price=np.float64(292.9233333333), timestamp=Timestamp('2022-03-03 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='SPY', size=np.float64(15.071956865978967), price=np.float64(420.2180557708), timestamp=Timestamp('2022-03-03 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='TSLA', size=np.float64(-64.8651816720574), price=np.float64(283.0333333333), timestamp=Timestamp('2022-03-04 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='SPY', size=np.float64(-15.071956865978967), price=np.float64(411.8989842192), timestamp=Timestamp('2022-03-04 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='BRK-B', size=np.float64(24.044014696132624), price=np.float64(322.66), timestamp=Timestamp('2022-03-04 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='AAPL', size=np.float64(39.93907977799788), price=np.float64(161.8724030235), timestamp=Timestamp('2022-03-04 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='AVGO', size=np.float64(93.63314885097188), price=np.float64(55.2371453704), timestamp=Timestamp('2022-03-04 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='JPM', size=np.float64(31.453042063281092), price=np.float64(123.3273679259), timestamp=Timestamp('2022-03-04 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0)),
#  Order(ticker='NVDA', size=np.float64(55.38085986985138), price=np.float64(23.3475422137), timestamp=Timestamp('2022-03-04 00:00:00+0000', tz='UTC'), slippage=0.0, commission=np.float64(0.0))]

# %%
"""
start with initial cash.
go through order history, update cash according to buy/sell.
make sure cash never goes negatie. i have allowd upto -100 because order recommendations
are generated based on previous day's closing price. next day's opening price, when the
order is executed, may be a bit higher, requiring slightly negative cash.
update position as we go along, and check if it ever goes negative
"""

"""
it is crucial to note that after backtesting is run on default_portfolio, it's internal states is changed.
at this point, even calling portfolio_registry.get('default') will return the changed version of 
the default portfolio. one must initiate a new registry and get a vanilla portfolio from there if needed.
"""

cash = PortfolioRegistry().get('default').cash
pos = PortfolioRegistry().get('default').positions
print("starting cash: ", cash)
print("starting position: ", pos)
for order in bt.manager.portfolio.order_history:
    if order.timestamp not in data[order.ticker].index:
        continue
    cash -= data[order.ticker]['adjOpen'].loc[order.timestamp] * order.size
    current = pos.get(order.ticker, 0)
    pos[order.ticker] = current + order.size
    if cash < -10:
        print(data[order.ticker]['adjOpen'].loc[order.timestamp], " ", order.price)
        print("negative cash: ", cash)
    if pos[order.ticker] < 0:
        print(order.ticker, " ", order.timestamp)
        print("negative position")


print("final cash: ", cash)
print("final position: ", pos)
# Out:
# starting cash:  25000.0
# starting position:  {}
# final cash:  0.0
# final position:  {'TSLA': np.float64(68.32575601202063), 'GOOG': np.float64(0.0), 'GOOGL': np.float64(15.78018561675245), 'BRK-B': np.float64(0.0), 'MSFT': np.float64(0.0), 'AAPL': np.float64(0.0), 'SPY': np.float64(0.0), 'AVGO': np.float64(0.0), 'JPM': np.float64(0.0), 'NVDA': np.float64(476.86038549101187), 'META': np.float64(0.0), 'AMZN': np.float64(32.866836836869886)}

# %%
bt.manager.portfolio.positions
# Out:
# {'TSLA': Position(ticker='TSLA', size=np.float64(68.32575601202063), last_trade_time=Timestamp('2022-12-30 00:00:00+0000', tz='UTC')),
#  'NVDA': Position(ticker='NVDA', size=np.float64(476.86038549101187), last_trade_time=Timestamp('2022-12-30 00:00:00+0000', tz='UTC')),
#  'AMZN': Position(ticker='AMZN', size=np.float64(32.866836836869886), last_trade_time=Timestamp('2022-12-30 00:00:00+0000', tz='UTC')),
#  'GOOGL': Position(ticker='GOOGL', size=np.float64(15.78018561675245), last_trade_time=Timestamp('2022-12-30 00:00:00+0000', tz='UTC'))}

# %%
"""
compute equity by adding up final cash and final position value.
for position we use the position calculated in the last step, 
as opposed to the output of the backtesting.
for ticker prices we use the final entry of the original dataframes, 
as opposed to the output of the backtesting.
"""
eq = cash + np.sum([pos[tk] * data[tk]['adjClose'].iloc[-1] for tk in bt.manager.positions])
print(eq)
# Out:
# 19525.89727403511
